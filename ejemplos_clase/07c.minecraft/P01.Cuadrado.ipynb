# %% [markdown]
# # P1. Automatización de creación de bloques
#
# ## P1.1 Creación de una línea de 4 bloques

# %% [markdown]
# ![linea.jpg](attachment:linea.jpg)

# %% [markdown]
# ## P1.2 Creación de un cuadrado de 5 bloques de lado

# %% [markdown]
# ![cuadrado.jpg](attachment:cuadrado.jpg)
